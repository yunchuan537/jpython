# %% [markdown]
# 上面这段代码只是为了演示 Jupyter notebook，这些不需要掌握哦，至少不需要现在掌握

# %% [markdown]
# ---

# %%
# %pylab inline

#plot([1,2,3], [1,0,1], marker='o')
plot([0,1], [2,3], marker='o')
# Out:
# Populating the interactive namespace from numpy and matplotlib
